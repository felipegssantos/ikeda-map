# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
field = pd.read_csv('../output.csv', header=None).map(complex)
field.head()
# Out:
#                          0                           1     \
# 0  1.386340e-49+0.000000e+00j  2.212040e-46+0.000000e+00j
# 1  8.470210e-03+1.578570e-03j  1.316100e-02+1.998690e-02j
# 2 -1.212010e-02+2.855910e-02j  9.901120e-03+5.511270e-03j
# 3  2.594040e-02-8.445320e-03j  1.862010e-02+2.320340e-02j
# 4  3.780110e-02-9.013150e-02j  3.051730e-02-6.866170e-02j
#
#                          2                           3     \
# 0  2.748790e-43+0.000000e+00j  2.660210e-40+0.000000e+00j
# 1  1.834470e-03+3.591220e-02j -2.102410e-02+4.987290e-02j
# 2  3.196940e-02-1.702430e-02j  5.270640e-02-3.414440e-02j
# 3  1.054030e-02+4.283000e-02j  1.146200e-03+4.785530e-02j
# 4  2.323490e-02-4.143970e-02j  2.008550e-02-1.427820e-02j
#
#                          4                           5     \
# 0  2.005010e-37+0.000000e+00j  1.176910e-34+0.000000e+00j
# 1 -4.427670e-02+5.964940e-02j -6.045460e-02+6.098650e-02j
# 2  7.005100e-02-4.800200e-02j  8.217650e-02-6.295860e-02j
# ...

# %%
field.loc[0, :].abs().plot()
field.loc[1, :].abs().plot()
# Out:
# <Axes: >

# %%
field.loc[0,:].abs().argmax()
# Out:
# np.int64(30)

# %%
field.loc[30:, 0].abs().plot()
# Out:
# <Axes: >

# %%
field.abs().sum(axis=1).plot()
# Out:
# <Axes: >

# %%
field.loc[3, :].abs().plot()
# Out:
# <Axes: >

# %%
field.loc[:, 100].abs().plot()
# Out:
# <Axes: >

# %%
plt.pcolormesh(field.abs().values, vmin=0.2)
plt.colorbar()

# %%
field.abs().stack().describe()
# Out:
# count    12928.000000
# mean         0.145990
# std          0.079887
# min          0.000000
# 25%          0.083893
# 50%          0.140438
# 75%          0.199638
# max          1.000000
# dtype: float64
